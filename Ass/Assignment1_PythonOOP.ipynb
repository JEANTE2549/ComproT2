# %% [markdown]
# ![AlternativeLogo-eng.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # CPE112: Programming with Data Structures
# ## Assignment1: Python OOP

# %% [markdown]
# # What is Python OOP?

# %% [markdown]
# <span style=color:red> Write here: </span>

# %% [markdown]
# **OOP** stand for Object-Oriented programming
#
# **What is it?** It is a programming paradigm based on the concept of <u>objects</u>, which can contain data in the form of properties and code in the form of methods.
#
# Core Concepts
# - **Objects:** instance of a class. Objects contain specific property values and can perform actions (methods).
# - **Class:** A base class or blueprint that defines the properties (attributes) and methods (behaviors) that its objects will have.
# - **Instantiation:** The process of creating a new instance (object) from a class using function notation ex. ```aMan = Person()```

# %% [markdown]
# ### I) Basic Class creation:
# Create a new class called __Car__ with
# 1. 4 data attributes e.g.; Brand, Model,...
# 2. 2 methods e.g.; display_info(), ....

# %% [markdown]
# <span style=color:red> Write the code below: </span>

# %%
class Car:
    '''create class car'''
    brand = 'Toyota'
    model = 'Altis'
    year = 2020
    color = 'White'

    def display_info(self):
        print(f'{self.brand} {self.model} years {self.year} {self.color} color')
    def hong(self):
        print(f'{self.brand} {self.model} years {self.year} {self.color} color brnnn.')

# %%
show = Car()

# %% [markdown]
# <span style=color:red> Test your class below: </span>

# %%
show.display_info()
# Out:
# Toyota Altis years 2020 White color

# %%
show.hong()
# Out:
# Toyota Altis years 2020 White color brnnn.

# %% [markdown]
# ---

# %% [markdown]
# ### II) Inheritance
# From your created new class in Practice I,
# 1. __Override__ one method from your base class
# 2. use _\_\_init\_\_( )_ method in your derived class
# 3. create 2 more methods

# %% [markdown]
# <span style=color:red> Write the code below: </span>

# %%
class Elec(Car):
    def __init__(self,brand,model,year,color,powerConsump):
        self.brand = brand
        self.model = model
        self.year = year
        self.color = color
        self.power = powerConsump
        
    def display_info(self):
        print(f'{self.brand} {self.model} years {self.year} {self.color} color,  {self.power} ahm')
    def F1(self):
        print('Yeah, it feels So good, I might just lose my mind')
    def autoPilot(self):
        if self.brand == 'Tesla':
            print('auto-pilot enable.')
        else:
            print('Drive by yourself.')

# %%
show1 = Elec('Toyota','Altis',2020,'White',1700)

# %% [markdown]
# <span style=color:red> Test your class below: </span>

# %%
show1.display_info()
# Out:
# Toyota Altis years 2020 White color,  1700 ahm

# %%
show1.autoPilot()
# Out:
# Drive by yourself.

# %% [markdown]
# ---

# %% [markdown]
# ### III) Encapsulation
# From your created class in Practice II,
# 1. Add 2 private attribute e.g.; owner, ...
# 2. Add setter and getter method

# %% [markdown]
# <span style=color:red> Write the code below: </span>

# %%
class Elec(Car):
    def __init__(self,brand,model,year,color,powerConsump,lockinPass,keyStart):
        self.brand = brand
        self.model = model
        self.year = year
        self.color = color
        self.power = powerConsump
        self.__password = lockinPass
        self.__key = keyStart
        
    def display_info(self):
        print(f'{self.brand} {self.model} years {self.year} {self.color} color,  {self.power} ahm')
    def F1(self):
        print('Yeah, it feels So good, I might just lose my mind')
    def autoPilot(self):
        if self.brand == 'Tesla':
            print('auto-pilot enable.')
        else:
            print('Drive by yourself.')
    def getPassUserRole(self):
        return self.__password
    def changePassAdminRole(self, lockinPass):
        self.__password = lockinPass

# %%
show2 = Elec('Toyota','Altis',2020,'White',1700,1234,'push')

# %% [markdown]
# <span style=color:red> Test your class below: </span>

# %%
show2.brand
# can call to show public attribute
# Out:
# 'Toyota'

# %%
show2.brand = 'Tesla'
show2.brand
# can call to show public attribute
# Out:
# 'Tesla'

# %%
show2.__password
# We can't call to show private attribute. It will get AttributeError
# But we can use return method to show private attribute
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 show2.__password
#       2 # We can't call to show private attribute. It will get AttributeError
#       3 # But we can use return method to show private attribute
#
# AttributeError: 'Elec' object has no attribute '__password'

# %%
show2.__password = 6767
show2.getPassUserRole()
# We can't change private attribute
# Out:
# 1234

# %%
show2.changePassAdminRole(6767)
# But we can change it by using method

# %%
show2.getPassUserRole()
# Out:
# 6767

# %% [markdown]
# ---

# %% [markdown]
# ### IV) Special Methods
# From your created class in Practice III,
# 1. add a special method _\_\_repr\_\_()_ to represent all infomation about this class

# %% [markdown]
# <span style=color:red> Write the code below: </span>

# %%
class Elec(Car):
    def __init__(self,brand,model,year,color,powerConsump,lockinPass,keyStart):
        self.brand = brand
        self.model = model
        self.year = year
        self.color = color
        self.power = powerConsump
        self.__password = lockinPass
        self.__key = keyStart

    def __repr__(self):
        return f"Car {self.brand} {self.model} {self.__password} {self.__key}"
    
    def display_info(self):
        print(f'{self.brand} {self.model} years {self.year} {self.color} color,  {self.power} ahm. {self.__password} {self.__key}')
    def F1(self):
        print('Yeah, it feels So good, I might just lose my mind')
    def autoPilot(self):
        if self.brand == 'Tesla':
            print('auto-pilot enable.')
        else:
            print('Drive by yourself.')
    def getPassUserRole(self):
        return self.__password
    def changePassAdminRole(self, lockinPass):
        self.__password = lockinPass

# %%
show3 = Elec('Toyota','Altis',2020,'White',1700,1234,'push')

# %% [markdown]
# <span style=color:red> Test your class below: </span>

# %%
print(repr(show3))
# Out:
# Car Toyota Altis 1234 push

# %%
show3.display_info()
# Out:
# Toyota Altis years 2020 White color,  1700 ahm. 1234 push

# %% [markdown]
# ---

# %% [markdown]
# ### Answer the question
# * What is the _\_\_init\_\__ function used for?
# * What 's happen when derive the classes from 2 or more classes
# * What is SOLID

# %% [markdown]
# <span style=color:red> Write here: </span>

# %% [markdown]
# 1. The ```__init__``` Function
#
# >   The ```__init__``` function is a special method used for the initialization of a class instance.

# %% [markdown]
# 2. Deriving from Two or More Classes
#
# > When a class is derived from two or more base classes, it is known as Multiple Inheritance.
# >
# > **Syntax:** ```class DerivedClassName (Base1, Base2, Base3):```

# %% [markdown]
# 3. What is SOLID?
#
# > SOLID acronym, they emphasize the foundational Object-Oriented Design Principles that these concepts build upon.
# >
# >SOLID Principles Overview:
# >- **Single Responsibility:** This aligns with the document's concept of Modularity, where a system is divided into separate functional
# units, each defined in a single file of source code.
# >- **Open-Closed:** This relates to Inheritance and Overriding, allowing software to be "open" for extension (adding new methods in
#  derived classes) but "closed" for modification of the base logic.
# >- **Liskov Substitution:** This is supported by the rule that an Object must be a valid instance of its Base Class, ensuring that a
# derived class (like a Student) can stand in for its parent class (a Person).
# >- **Interface Segregation:** This is mirrored by Abstraction, which involves refining a complicated system down to its most fundamental > >parts and explaining only the necessary functionality.
# >- **Dependency Inversion:** This is supported by Encapsulation, which ensures that components do not reveal internal details, allowing high-level logic to depend on abstractions rather than specific internal implementations.

# %% [markdown]
# ---

# %% [markdown]
# # Lecture

# %% [markdown]
# ## Object-Oriented Programming (OOP).
#
# Core Concepts
# - **Objects:** instance of a class. Objects contain specific property values and can perform actions (methods).
# - **Class:** A base class or blueprint that defines the properties (attributes) and methods (behaviors) that its objects will have.
# - **Instantiation:** The process of creating a new instance (object) from a class using function notation ex. ```aMan = Person()```
#
# Key Benefits of OOP
# - **Robustness**
# - **Adaptability**
# - **Reusability**
#
# ---
#
# Object-Oriented Design Principles
# - **Modularity**
# - **Abstraction**
# - **Encapsulation**
#
# ---
#
# Class Mechanics in Python
# - **Initialization:** Python uses the special ```__init__()``` method to initialize a class instance when it is created
# - **Attributes:** These consist of Data Attributes (variables) and Methods (functions belonging to the object).
# - **Self:** Used within class methods to refer to the specific instance of the object (e.g., ```self.name```).
#
# ---
#
# Inheritance and Access Modifiers
# - __Inheritance:__ Allows a <u>Derived Class</u> to take on the properties and methods of a <u>Base Class</u>.
# - __Overriding:__ When a derived class provides a new implementation for a method that already exists in its base class.
# - __Access Modifiers:__
#     - **Public:** Accessible from outside the class; the default in Python.
#     - **Protected:** Indicated by a single underscore (```_```). It is a convention suggesting the variable is non-public, but it is not strictly enforced.
#     - **Private:** Indicated by double underscores (```__```). This makes it harder to access from outside and is used to avoid name clashes in subclasses.
#
# ---
#
# Iterators and Generators
# - **Iterators:** Objects that contain a countable number of values and implement the ```__iter__()``` and ```__next__()``` methods.
# - **Generators:** A subset of iterators that are written like regular functions but use the yield statement to return data one at a time.
